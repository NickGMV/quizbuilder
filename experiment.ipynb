# %%
x = '''{"Q1":{"Question":"<p>What is your name?<\/p>","Correctanswer":"<p>Nick<\/p>","Explanation":"Your name","mode":"click the correct answer","incorrect":["<p>Bob<\/p>","<p>Tim<\/p>","<p>Jerry<\/p>","<p>Mark<\/p>"]},"Q2":{"Question":"<p>What is their quest?<\/p>","Correctanswer":"<p>To make quizes work<\/p>","Explanation":"Pick one","mode":"click the correct answer","incorrect":["<p>To code stuff<\/p>","<p>To waste time using silly examples<\/p>"]},"Q3":{"Question":"<p>What is your favourite colour?<\/p>","Correctanswer":"<p>yellow<\/p>","Explanation":"na","mode":"click the correct answer","incorrect":["<p>green<\/p>","<p>puise<\/p>","<p>red<\/p>"]},"Q4":{"Question":"<p>What is the capital of Assyria?<\/p>","Correctanswer":"<p>Assur<\/p>","Explanation":"na","mode":"click the correct answer","incorrect":["<p>Asur<\/p>"]},"Q5":{"Question":"<p>What is the air speed velocity of an unburdened swallow?<\/p>","Correctanswer":"<p>I don't know<\/p>","Explanation":"Simple stuff really - watch your python","mode":"click the correct answer","incorrect":["<p>5m\/s<\/p>","<p>35m\/s<\/p>","<p>10m\/s<\/p>"]},"Q6":{"Question":"<p>&#x200b;<math xmlns=\"http:\/\/www.w3.org\/1998\/Math\/MathML\" display=\"inline\"><mrow><msup><mi>x<\/mi><mn>2<\/mn><\/msup><mo>&#x0002A;<\/mo><msup><mi>x<\/mi><mn>3<\/mn><\/msup><\/mrow><\/math><\/p>","Correctanswer":"<p>&#x200b;<math xmlns=\"http:\/\/www.w3.org\/1998\/Math\/MathML\" display=\"inline\"><mrow><msup><mi>x<\/mi><mn>5<\/mn><\/msup><\/mrow><\/math><\/p>","Explanation":"na","mode":"na","incorrect":["<p>&#x200b;<math xmlns=\"http:\/\/www.w3.org\/1998\/Math\/MathML\" display=\"inline\"><mrow><msup><mi>x<\/mi><mn>2<\/mn><\/msup><mo>&#x0002B;<\/mo><msup><mi>x<\/mi><mn>3<\/mn><\/msup><\/mrow><\/math><\/p>"]}}'''

#x[1128]
x[1120:1160]
# Out:
# 'wer":"<p>&#x200b;<math xmlns="http:\\/\\/w'

# %%
import mdtex2html
#from sympy.interactive import printing
#printing.init_printing(use_latex = True)
import numpy as np
#import sympy as sp

# %%
import pandas as pd


df = pd.read_excel('./quiz questions.xlsx')
df.head()
# Out:
#                                             Question        Correctanswer  \
# 0                                 What is your name?                 Nick
# 1                               What is their quest?  To make quizes work
# 2                     What is your favourite colour?               yellow
# 3                    What is the capital of Assyria?                Assur
# 4  What is the air speed velocity of an unburdene...         I don't know
#
#       incorrect1                          incorrect2 incorrect3 incorrect4  \
# 0            Bob                                 Tim      Jerry       Mark
# 1  To code stuff  To waste time using silly examples        NaN        NaN
# 2          green                               puise        red        NaN
# 3           Asur                                 NaN        NaN        NaN
# 4           5m/s                               35m/s      10m/s        NaN
#
#                                Explanation                      mode
# ...

# %%
def convert1(x):
    y = f'{x}'
    print(y)
    #eval('x = "{x}"')
    z = mdtex2html.convert(y)
    print(z)
    return z

df['Correctanswer'] = df['Correctanswer'].apply(convert1)
df.head()
# Out:
# Nick
# <p>Nick</p>
# To make quizes work
# <p>To make quizes work</p>
# yellow
# <p>yellow</p>
# Assur
# <p>Assur</p>
# I don't know
# <p>I don't know</p>
# $x^5$
# <p>&#x200b;<math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><mrow><msup><mi>x</mi><mn>5</mn></msup></mrow></math></p>
# 17
# <p>17</p>
#                                             Question  \
# 0                                 What is your name?
# 1                               What is their quest?
# 2                     What is your favourite colour?
# 3                    What is the capital of Assyria?
# 4  What is the air speed velocity of an unburdene...
#
#                 Correctanswer     incorrect1  \
# 0                 <p>Nick</p>            Bob
# 1  <p>To make quizes work</p>  To code stuff
# 2               <p>yellow</p>          green
# 3                <p>Assur</p>           Asur
# 4         <p>I don't know</p>           5m/s
#
# ...
